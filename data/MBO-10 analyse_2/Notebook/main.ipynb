# %%
from visu_imbalance import processing
import glob
import os
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_rows', None)
from tqdm import tqdm
from events_rares import visu, Garman_Klauss

import plotly.graph_objects as go

# %%
# df = pd.read_csv("/Volumes/T9/CSV_GOOGL_NASDAQ_PL_cours/20-9-2024.csv")
# time = pd.to_datetime(df["time"])
# prix = df['price']

# fig = go.Figure()
# fig.add_trace(go.Scatter(x=time, y=prix, mode='lines', line=dict(color='green', width=2), name='Intensités extrêmes'))

# fig.show()

# %%
#Garman_Klauss("/Volumes/T9/CSV_GOOGL_NASDAQ_PL", 'GOOGL')

# %%
df = visu("/Volumes/T9/CSV_GOOGL_NASDAQ_PL", 'GOOGL')
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
print(len('Garman-Klass vol 5m'))
# Out:
# 19

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [date, nombre de trades, variance, max_proba, min_proba, variance_proba, intensité max, seuil, vol_GK]
# Index: []

# %%
files_csv = glob.glob(os.path.join("/Volumes/T9/CSV_dezippe_nasdaq", "*.csv"))
files_csv = ['/Users/edouard/Desktop/EA p1  HFT/HFT_QR_RL_save/Sans titre/HFT_QR_RL/data/MBO-10 analyse/Notebooks/MBO_10_RIOT']
output = '/Users/edouard/Desktop/Rosenbaum'
for f in tqdm(range(0, len(files_csv))):
    processing(files_csv[f], output)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 3251813
# 3251727
# 1999210
# 1999210
#   0%|          | 0/1 [00:19<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/12/xfmxn01n5f77jxyprmtcnb6m0000gn/T/ipykernel_51611/2766011497.py in ?()
#       4 files_csv = glob.glob(os.path.join("/Volumes/T9/CSV_dezippe_nasdaq", "*.csv"))
# ----> 5 files_csv = ['/Users/edouard/Desktop/EA p1  HFT/HFT_QR_RL_save/Sans titre/HFT_QR_RL/data/MBO-10 analyse/Notebooks/MBO_10_RIOT']
#       6 output = '/Users/edouard/Desktop/Rosenbaum'
#       7 for f in tqdm(range(0, len(files_csv))):
#       8     processing(files_csv[f], output)
#
# ~/Desktop/EA p1  HFT/HFT_QR_RL_save/Sans titre/HFT_QR_RL/data/MBO-10 analyse_2/Notebook/visu_imbalance.py in ?(file, output)
#      38     df_['nb_ppl_opposite'] = np.where(df['side'] == 'A', df[f'bid_ct_0{limite}'], df[f'ask_ct_0{limite}'])
# ...
